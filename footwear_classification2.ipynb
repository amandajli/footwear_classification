# %% [markdown]
# # Image Classification for Footwear

# %% [markdown]
# ## Setup
#
# Import TensorFlow and other necessary libraries:

# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
import os

# %% [markdown]
# Upload the zip file for the footwear classification dataset, and change the following path to whatever you name the folder. You can find the path by clicking the three dots by the side of the folder and clicking "copy path"

# %%
# !unzip /content/footwear.zip

# %%
import os
dir_path = r'/content/footwear/Boot'
count = 0
# Iterate directory
for path in os.listdir(dir_path):
    # check if current path is a file
    if os.path.isfile(os.path.join(dir_path, path)):
        count += 1
print('File count:', count)
# should print out 5000
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-8a28dcfcb418> in <module>
#       3 count = 0
#       4 # Iterate directory
# ----> 5 for path in os.listdir(dir_path):
#       6     # check if current path is a file
#       7     if os.path.isfile(os.path.join(dir_path, path)):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/footwear/Boot'

# %% [markdown]
# ## Download and explore the dataset

# %% [markdown]
# After downloading, you should now have a copy of the dataset available. There are 15,000 total images:

# %%
import pathlib
data_dir = pathlib.Path("/content/footwear")

image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 15000

# %% [markdown]
# Here are some boots:

# %%
boots = list(data_dir.glob('Boot/*'))
img = PIL.Image.open(str(boots[0]))
print(img.width)
print(img.height)
# Out:
# 136
# 102

# %%
sandals = list(data_dir.glob('Sandal/*'))
PIL.Image.open(str(sandals[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=136x102 at 0x7F210FEAD880>

# %%
shoes = list(data_dir.glob('Shoe/*'))
PIL.Image.open(str(shoes[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=136x102 at 0x7F210FCC91C0>

# %% [markdown]
# ## Load data using a Keras utility
#
# Next, load these images off disk using the helpful `tf.keras.utils.image_dataset_from_directory` utility. This will take you from a directory of images on disk to a `tf.data.Dataset` in just a couple lines of code. If you like, you can also write your own data loading code from scratch by visiting the [Load and preprocess images](../load_data/images.ipynb) tutorial.

# %% [markdown]
# ### Create a dataset

# %% [markdown]
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# It's good practice to use a validation split when developing your model. Use 80% of the images for training and 20% for validation.

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 15000 files belonging to 3 classes.
# Using 12000 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 15000 files belonging to 3 classes.
# Using 3000 files for validation.

# %% [markdown]
# You can find the class names in the `class_names` attribute on these datasets. These correspond to the directory names in alphabetical order.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['Boot', 'Sandal', 'Shoe']

# %% [markdown]
# ## Visualize the data
#
# Here are the first nine images from the training dataset:

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# You will pass these datasets to the Keras `Model.fit` method for training later in this tutorial. If you like, you can also manually iterate over the dataset and retrieve batches of images:

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break

count = 0
for image_batch, labels_batch in train_ds:
  count += 1
print(count)
# Out:
# (32, 180, 180, 3)
# (32,)
# 375

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.
#
# You can call `.numpy()` on the `image_batch` and `labels_batch` tensors to convert them to a `numpy.ndarray`.

# %% [markdown]
# ## Configure the dataset for performance
#
# Make sure to use buffered prefetching, so you can yield data from disk without having I/O become blocking. These are two important methods you should use when loading data:
#
# - `Dataset.cache` keeps the images in memory after they're loaded off disk during the first epoch. This will ensure the dataset does not become a bottleneck while training your model. If your dataset is too large to fit into memory, you can also use this method to create a performant on-disk cache.
# - `Dataset.prefetch` overlaps data preprocessing and model execution while training.
#
# Interested readers can learn more about both methods, as well as how to cache data to disk in the *Prefetching* section of the [Better performance with the tf.data API](../../guide/data_performance.ipynb) guide.

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## Standardize the data

# %% [markdown]
# The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network; in general you should seek to make your input values small.
#
# Here, you will standardize values to be in the `[0, 1]` range by using `tf.keras.layers.Rescaling`:

# %%
normalization_layer = layers.Rescaling(1./255)

# %% [markdown]
# Or, you can include the layer inside your model definition, which can simplify deployment. Use the second approach here.

# %% [markdown]
# Note: You previously resized images using the `image_size` argument of `tf.keras.utils.image_dataset_from_directory`. If you want to include the resizing logic in your model as well, you can use the `tf.keras.layers.Resizing` layer.

# %% [markdown]
# ## A basic Keras model
#
# ### Create the model
#
# The Keras [Sequential](https://www.tensorflow.org/guide/keras/sequential_model) model consists of three convolution blocks (`tf.keras.layers.Conv2D`) with a max pooling layer (`tf.keras.layers.MaxPooling2D`) in each of them. There's a fully-connected layer (`tf.keras.layers.Dense`) with 128 units on top of it that is activated by a ReLU activation function (`'relu'`). This model has not been tuned for high accuracy; the goal of this tutorial is to show a standard approach.

# %%
# num_classes = len(class_names)

# model = Sequential([
#   layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
#   layers.Conv2D(2, 3, padding='same', activation='relu'),
#   layers.MaxPooling2D(),
#   layers.Conv2D(4, 3, padding='same', activation='relu'),
#   layers.MaxPooling2D(),
#   layers.Conv2D(8, 3, padding='same', activation='relu'),
#   layers.MaxPooling2D(),
#   layers.Conv2D(16, 3, padding='same', activation='relu'),
#   layers.MaxPooling2D(),
#   layers.Conv2D(32, 3, padding='same', activation='relu'),
#   layers.MaxPooling2D(),
#   layers.Conv2D(32, 3, padding='same', activation='relu'),
#   layers.MaxPooling2D(),
#   layers.Flatten(),
#   layers.Dense(32, activation='relu'),
#   layers.Dense(num_classes)
# ])

# %%
# num_classes = len(class_names)

model = Sequential([
  layers.Rescaling(1./255, input_shape=(64, 64, 3)),
  layers.Conv2D(16, 5, padding='same', activation='relu', strides=(2,2)),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 5, padding='same', activation='relu',strides=(2,2)),
  layers.MaxPooling2D(),
  layers.Conv2D(8, 5, padding='same', activation='relu',strides=(2,2)),
  layers.Flatten(),
  layers.Dense(2)
])

# %% [markdown]
# ### Compile the model
#
# For this tutorial, choose the `tf.keras.optimizers.Adam` optimizer and `tf.keras.losses.SparseCategoricalCrossentropy` loss function. To view training and validation accuracy for each training epoch, pass the `metrics` argument to `Model.compile`.

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# (45, 45, 4)
# (45, 45, 8)
# filter size: 3x3x4
# (36+1)*8

# %% [markdown]
# ### Model summary
#
# View all the layers of the network using the Keras `Model.summary` method:

# %%
model.summary()

#adjust your layers and filter numbers to have under 100,000 parameters
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 64, 64, 3)         0
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 16)        1216
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 16)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 64)          25664
#
#  max_pooling2d_3 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 2, 2, 8)           12808
#
#  flatten_1 (Flatten)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 39,754
# Trainable params: 39,754
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %% [markdown]
# Train the model for 10 epochs with the Keras `Model.fit` method:

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 0.00001),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

epochs=100
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/100
# 375/375 [==============================] - 37s 40ms/step - loss: 0.5634 - accuracy: 0.7872 - val_loss: 0.3268 - val_accuracy: 0.8827
# Epoch 2/100
# 375/375 [==============================] - 12s 32ms/step - loss: 0.2792 - accuracy: 0.9007 - val_loss: 0.2712 - val_accuracy: 0.8993
# Epoch 3/100
# 375/375 [==============================] - 12s 32ms/step - loss: 0.2131 - accuracy: 0.9252 - val_loss: 0.2021 - val_accuracy: 0.9320
# Epoch 4/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.1789 - accuracy: 0.9377 - val_loss: 0.1841 - val_accuracy: 0.9380
# Epoch 5/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.1526 - accuracy: 0.9435 - val_loss: 0.1681 - val_accuracy: 0.9373
# Epoch 6/100
# 375/375 [==============================] - 12s 32ms/step - loss: 0.1395 - accuracy: 0.9497 - val_loss: 0.1474 - val_accuracy: 0.9473
# Epoch 7/100
# 375/375 [==============================] - 12s 32ms/step - loss: 0.1211 - accuracy: 0.9559 - val_loss: 0.1522 - val_accuracy: 0.9503
# Epoch 8/100
# 375/375 [==============================] - 12s 32ms/step - loss: 0.1085 - accuracy: 0.9614 - val_loss: 0.1487 - val_accuracy: 0.9473
# Epoch 9/100
# 375/375 [==============================] - 12s 32ms/step - loss: 0.0994 - accuracy: 0.9654 - val_loss: 0.1185 - val_accuracy: 0.9593
# Epoch 10/100
# 375/375 [==============================] - 12s 32ms/step - loss: 0.0907 - accuracy: 0.9689 - val_loss: 0.1169 - val_accuracy: 0.9597
# Epoch 11/100
# 375/375 [==============================] - 12s 32ms/step - loss: 0.0809 - accuracy: 0.9730 - val_loss: 0.1039 - val_accuracy: 0.9663
# Epoch 12/100
# 375/375 [==============================] - 12s 32ms/step - loss: 0.0763 - accuracy: 0.9732 - val_loss: 0.1017 - val_accuracy: 0.9647
# Epoch 13/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0702 - accuracy: 0.9763 - val_loss: 0.0960 - val_accuracy: 0.9657
# Epoch 14/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0643 - accuracy: 0.9776 - val_loss: 0.1004 - val_accuracy: 0.9660
# Epoch 15/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0584 - accuracy: 0.9808 - val_loss: 0.0946 - val_accuracy: 0.9683
# Epoch 16/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0533 - accuracy: 0.9837 - val_loss: 0.0883 - val_accuracy: 0.9703
# Epoch 17/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0536 - accuracy: 0.9822 - val_loss: 0.0894 - val_accuracy: 0.9683
# Epoch 18/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0465 - accuracy: 0.9847 - val_loss: 0.0794 - val_accuracy: 0.9740
# Epoch 19/100
# 375/375 [==============================] - 12s 32ms/step - loss: 0.0429 - accuracy: 0.9862 - val_loss: 0.0883 - val_accuracy: 0.9720
# Epoch 20/100
# 375/375 [==============================] - 12s 32ms/step - loss: 0.0394 - accuracy: 0.9876 - val_loss: 0.0796 - val_accuracy: 0.9730
# Epoch 21/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0377 - accuracy: 0.9881 - val_loss: 0.0826 - val_accuracy: 0.9737
# Epoch 22/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0338 - accuracy: 0.9900 - val_loss: 0.0924 - val_accuracy: 0.9683
# Epoch 23/100
# 375/375 [==============================] - 12s 32ms/step - loss: 0.0307 - accuracy: 0.9910 - val_loss: 0.0920 - val_accuracy: 0.9700
# Epoch 24/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0273 - accuracy: 0.9923 - val_loss: 0.0928 - val_accuracy: 0.9670
# Epoch 25/100
# 375/375 [==============================] - 12s 32ms/step - loss: 0.0267 - accuracy: 0.9919 - val_loss: 0.0712 - val_accuracy: 0.9797
# Epoch 26/100
# 375/375 [==============================] - 12s 32ms/step - loss: 0.0227 - accuracy: 0.9937 - val_loss: 0.0710 - val_accuracy: 0.9790
# Epoch 27/100
# 375/375 [==============================] - 12s 32ms/step - loss: 0.0211 - accuracy: 0.9946 - val_loss: 0.0932 - val_accuracy: 0.9720
# Epoch 28/100
# 375/375 [==============================] - 12s 32ms/step - loss: 0.0201 - accuracy: 0.9941 - val_loss: 0.0763 - val_accuracy: 0.9753
# Epoch 29/100
# 375/375 [==============================] - 12s 32ms/step - loss: 0.0184 - accuracy: 0.9949 - val_loss: 0.0745 - val_accuracy: 0.9780
# Epoch 30/100
# 375/375 [==============================] - 13s 33ms/step - loss: 0.0157 - accuracy: 0.9960 - val_loss: 0.0754 - val_accuracy: 0.9763
# Epoch 31/100
# 375/375 [==============================] - 12s 32ms/step - loss: 0.0155 - accuracy: 0.9953 - val_loss: 0.0744 - val_accuracy: 0.9780
# Epoch 32/100
# 375/375 [==============================] - 12s 32ms/step - loss: 0.0140 - accuracy: 0.9965 - val_loss: 0.0691 - val_accuracy: 0.9803
# Epoch 33/100
# 375/375 [==============================] - 12s 32ms/step - loss: 0.0140 - accuracy: 0.9962 - val_loss: 0.0676 - val_accuracy: 0.9813
# Epoch 34/100
# 375/375 [==============================] - 12s 32ms/step - loss: 0.0104 - accuracy: 0.9978 - val_loss: 0.0743 - val_accuracy: 0.9800
# Epoch 35/100
# 375/375 [==============================] - 12s 32ms/step - loss: 0.0110 - accuracy: 0.9978 - val_loss: 0.0682 - val_accuracy: 0.9823
# Epoch 36/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0099 - accuracy: 0.9984 - val_loss: 0.0869 - val_accuracy: 0.9737
# Epoch 37/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0079 - accuracy: 0.9987 - val_loss: 0.0740 - val_accuracy: 0.9803
# Epoch 38/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0068 - accuracy: 0.9991 - val_loss: 0.0743 - val_accuracy: 0.9817
# Epoch 39/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0086 - accuracy: 0.9977 - val_loss: 0.0713 - val_accuracy: 0.9807
# Epoch 40/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0073 - accuracy: 0.9984 - val_loss: 0.0737 - val_accuracy: 0.9790
# Epoch 41/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0051 - accuracy: 0.9992 - val_loss: 0.0870 - val_accuracy: 0.9777
# Epoch 42/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0047 - accuracy: 0.9992 - val_loss: 0.0753 - val_accuracy: 0.9813
# Epoch 43/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0059 - accuracy: 0.9979 - val_loss: 0.0848 - val_accuracy: 0.9773
# Epoch 44/100
# 375/375 [==============================] - 12s 32ms/step - loss: 0.0068 - accuracy: 0.9985 - val_loss: 0.0750 - val_accuracy: 0.9820
# Epoch 45/100
# 375/375 [==============================] - 12s 32ms/step - loss: 0.0029 - accuracy: 0.9997 - val_loss: 0.0737 - val_accuracy: 0.9830
# Epoch 46/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0039 - accuracy: 0.9992 - val_loss: 0.0785 - val_accuracy: 0.9810
# Epoch 47/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0026 - accuracy: 0.9996 - val_loss: 0.0784 - val_accuracy: 0.9820
# Epoch 48/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0032 - accuracy: 0.9992 - val_loss: 0.0780 - val_accuracy: 0.9807
# Epoch 49/100
# 375/375 [==============================] - 13s 34ms/step - loss: 0.0037 - accuracy: 0.9992 - val_loss: 0.1018 - val_accuracy: 0.9737
# Epoch 50/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0116 - accuracy: 0.9959 - val_loss: 0.0797 - val_accuracy: 0.9817
# Epoch 51/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0025 - accuracy: 0.9998 - val_loss: 0.0790 - val_accuracy: 0.9823
# Epoch 52/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0016 - accuracy: 0.9998 - val_loss: 0.0786 - val_accuracy: 0.9823
# Epoch 53/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0024 - accuracy: 0.9995 - val_loss: 0.0783 - val_accuracy: 0.9823
# Epoch 54/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0016 - accuracy: 0.9998 - val_loss: 0.0803 - val_accuracy: 0.9813
# Epoch 55/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.0810 - val_accuracy: 0.9810
# Epoch 56/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0015 - accuracy: 0.9998 - val_loss: 0.0837 - val_accuracy: 0.9830
# Epoch 57/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0041 - accuracy: 0.9992 - val_loss: 0.0847 - val_accuracy: 0.9800
# Epoch 58/100
# 375/375 [==============================] - 12s 33ms/step - loss: 8.8325e-04 - accuracy: 1.0000 - val_loss: 0.0831 - val_accuracy: 0.9827
# Epoch 59/100
# 375/375 [==============================] - 12s 33ms/step - loss: 5.9293e-04 - accuracy: 1.0000 - val_loss: 0.0852 - val_accuracy: 0.9810
# Epoch 60/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0101 - accuracy: 0.9962 - val_loss: 0.0996 - val_accuracy: 0.9773
# Epoch 61/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 0.0802 - val_accuracy: 0.9833
# Epoch 62/100
# 375/375 [==============================] - 12s 33ms/step - loss: 7.6760e-04 - accuracy: 1.0000 - val_loss: 0.0823 - val_accuracy: 0.9827
# Epoch 63/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0876 - val_accuracy: 0.9817
# Epoch 64/100
# 375/375 [==============================] - 12s 33ms/step - loss: 6.1113e-04 - accuracy: 1.0000 - val_loss: 0.0866 - val_accuracy: 0.9810
# Epoch 65/100
# 375/375 [==============================] - 12s 33ms/step - loss: 4.6368e-04 - accuracy: 1.0000 - val_loss: 0.0939 - val_accuracy: 0.9820
# Epoch 66/100
# 375/375 [==============================] - 12s 33ms/step - loss: 8.8547e-04 - accuracy: 0.9999 - val_loss: 0.1289 - val_accuracy: 0.9727
# Epoch 67/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0070 - accuracy: 0.9982 - val_loss: 0.0999 - val_accuracy: 0.9763
# Epoch 68/100
# 375/375 [==============================] - 13s 33ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0840 - val_accuracy: 0.9810
# Epoch 69/100
# 375/375 [==============================] - 12s 33ms/step - loss: 4.9530e-04 - accuracy: 1.0000 - val_loss: 0.0937 - val_accuracy: 0.9793
# Epoch 70/100
# 375/375 [==============================] - 12s 33ms/step - loss: 5.4089e-04 - accuracy: 1.0000 - val_loss: 0.0895 - val_accuracy: 0.9813
# Epoch 71/100
# 375/375 [==============================] - 12s 33ms/step - loss: 3.9255e-04 - accuracy: 1.0000 - val_loss: 0.0894 - val_accuracy: 0.9820
# Epoch 72/100
# 375/375 [==============================] - 13s 34ms/step - loss: 3.6368e-04 - accuracy: 1.0000 - val_loss: 0.0912 - val_accuracy: 0.9827
# Epoch 73/100
# 375/375 [==============================] - 12s 33ms/step - loss: 3.7632e-04 - accuracy: 1.0000 - val_loss: 0.0910 - val_accuracy: 0.9817
# Epoch 74/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0058 - accuracy: 0.9977 - val_loss: 0.0971 - val_accuracy: 0.9793
# Epoch 75/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0041 - accuracy: 0.9987 - val_loss: 0.0860 - val_accuracy: 0.9793
# Epoch 76/100
# 375/375 [==============================] - 12s 33ms/step - loss: 5.2289e-04 - accuracy: 1.0000 - val_loss: 0.0878 - val_accuracy: 0.9810
# Epoch 77/100
# 375/375 [==============================] - 12s 33ms/step - loss: 3.6701e-04 - accuracy: 1.0000 - val_loss: 0.0887 - val_accuracy: 0.9813
# Epoch 78/100
# 375/375 [==============================] - 12s 33ms/step - loss: 3.5398e-04 - accuracy: 1.0000 - val_loss: 0.0897 - val_accuracy: 0.9830
# Epoch 79/100
# 375/375 [==============================] - 13s 34ms/step - loss: 3.6125e-04 - accuracy: 1.0000 - val_loss: 0.0890 - val_accuracy: 0.9820
# Epoch 80/100
# 375/375 [==============================] - 12s 33ms/step - loss: 5.7388e-04 - accuracy: 1.0000 - val_loss: 0.0950 - val_accuracy: 0.9790
# Epoch 81/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0045 - accuracy: 0.9987 - val_loss: 0.0904 - val_accuracy: 0.9807
# Epoch 82/100
# 375/375 [==============================] - 12s 33ms/step - loss: 7.9698e-04 - accuracy: 0.9999 - val_loss: 0.0935 - val_accuracy: 0.9800
# Epoch 83/100
# 375/375 [==============================] - 12s 33ms/step - loss: 3.3707e-04 - accuracy: 1.0000 - val_loss: 0.0989 - val_accuracy: 0.9803
# Epoch 84/100
# 375/375 [==============================] - 12s 33ms/step - loss: 3.5322e-04 - accuracy: 1.0000 - val_loss: 0.0922 - val_accuracy: 0.9803
# Epoch 85/100
# 375/375 [==============================] - 12s 33ms/step - loss: 1.6930e-04 - accuracy: 1.0000 - val_loss: 0.0927 - val_accuracy: 0.9803
# Epoch 86/100
# 375/375 [==============================] - 12s 33ms/step - loss: 1.7348e-04 - accuracy: 1.0000 - val_loss: 0.0964 - val_accuracy: 0.9790
# Epoch 87/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0060 - accuracy: 0.9982 - val_loss: 0.0915 - val_accuracy: 0.9790
# Epoch 88/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.0910 - val_accuracy: 0.9803
# Epoch 89/100
# 375/375 [==============================] - 12s 33ms/step - loss: 3.9666e-04 - accuracy: 1.0000 - val_loss: 0.0922 - val_accuracy: 0.9817
# Epoch 90/100
# 375/375 [==============================] - 13s 33ms/step - loss: 2.3412e-04 - accuracy: 1.0000 - val_loss: 0.0970 - val_accuracy: 0.9800
# Epoch 91/100
# 375/375 [==============================] - 12s 33ms/step - loss: 1.9884e-04 - accuracy: 1.0000 - val_loss: 0.0955 - val_accuracy: 0.9807
# Epoch 92/100
# 375/375 [==============================] - 12s 33ms/step - loss: 2.0559e-04 - accuracy: 1.0000 - val_loss: 0.0991 - val_accuracy: 0.9797
# Epoch 93/100
# 375/375 [==============================] - 12s 33ms/step - loss: 2.2335e-04 - accuracy: 1.0000 - val_loss: 0.0990 - val_accuracy: 0.9817
# Epoch 94/100
# 375/375 [==============================] - 12s 33ms/step - loss: 1.7473e-04 - accuracy: 1.0000 - val_loss: 0.1394 - val_accuracy: 0.9743
# Epoch 95/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0083 - accuracy: 0.9977 - val_loss: 0.0866 - val_accuracy: 0.9820
# Epoch 96/100
# 375/375 [==============================] - 12s 33ms/step - loss: 4.9917e-04 - accuracy: 1.0000 - val_loss: 0.0919 - val_accuracy: 0.9800
# Epoch 97/100
# 375/375 [==============================] - 12s 33ms/step - loss: 2.5760e-04 - accuracy: 1.0000 - val_loss: 0.0920 - val_accuracy: 0.9800
# Epoch 98/100
# 375/375 [==============================] - 12s 33ms/step - loss: 2.1920e-04 - accuracy: 1.0000 - val_loss: 0.0940 - val_accuracy: 0.9817
# Epoch 99/100
# 375/375 [==============================] - 12s 33ms/step - loss: 1.6538e-04 - accuracy: 1.0000 - val_loss: 0.0949 - val_accuracy: 0.9810
# Epoch 100/100
# 375/375 [==============================] - 12s 33ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 0.0994 - val_accuracy: 0.9813

# %% [markdown]
# ## Visualize training results

# %% [markdown]
# Create plots of the loss and accuracy on the training and validation sets:

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# The plots show that training accuracy and validation accuracy are off by large margins, and the model has achieved only around 60% accuracy on the validation set.
#
# The following tutorial sections show how to inspect what went wrong and try to increase the overall performance of the model.

# %% [markdown]
# ## Overfitting

# %% [markdown]
# In the plots above, the training accuracy is increasing linearly over time, whereas validation accuracy stalls around 60% in the training process. Also, the difference in accuracy between training and validation accuracy is noticeable—a sign of [overfitting](https://www.tensorflow.org/tutorials/keras/overfit_and_underfit).
#
# When there are a small number of training examples, the model sometimes learns from noises or unwanted details from training examples—to an extent that it negatively impacts the performance of the model on new examples. This phenomenon is known as overfitting. It means that the model will have a difficult time generalizing on a new dataset.
#
# There are multiple ways to fight overfitting in the training process. In this tutorial, you'll use *data augmentation* and add *dropout* to your model.

# %% [markdown]
# ## Data augmentation

# %% [markdown]
# Overfitting generally occurs when there are a small number of training examples. [Data augmentation](./data_augmentation.ipynb) takes the approach of generating additional training data from your existing examples by augmenting them using random transformations that yield believable-looking images. This helps expose the model to more aspects of the data and generalize better.
#
# You will implement data augmentation using the following Keras preprocessing layers: `tf.keras.layers.RandomFlip`, `tf.keras.layers.RandomRotation`, and `tf.keras.layers.RandomZoom`. These can be included inside your model like other layers, and run on the GPU.

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

# %% [markdown]
# Visualize a few augmented examples by applying data augmentation to the same image several times:

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# You will add data augmentation to your model before training in the next step.

# %% [markdown]
# ## Dropout
#
# Another technique to reduce overfitting is to introduce [dropout](https://developers.google.com/machine-learning/glossary#dropout_regularization){:.external} regularization to the network.
#
# When you apply dropout to a layer, it randomly drops out (by setting the activation to zero) a number of output units from the layer during the training process. Dropout takes a fractional number as its input value, in the form such as 0.1, 0.2, 0.4, etc. This means dropping out 10%, 20% or 40% of the output units randomly from the applied layer.
#
# Create a new neural network with `tf.keras.layers.Dropout` before training it using the augmented images:

# %%
model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes, name="outputs")
])

# %% [markdown]
# ## Compile and train the model

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 0.00001),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_2 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 180, 180, 16)      448
#
#  max_pooling2d_3 (MaxPooling  (None, 90, 90, 16)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_4 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 30976)             0
#
#  dense_2 (Dense)             (None, 128)               3965056
#
#  dense_3 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 3,989,027
# Trainable params: 3,989,027
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 15
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)

# %% [markdown]
# ## Visualize training results
#
# After applying data augmentation and `tf.keras.layers.Dropout`, there is less overfitting than before, and training and validation accuracy are closer aligned:

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Predict on new data

# %% [markdown]
# Use your model to classify an image that wasn't included in the training or validation sets.

# %% [markdown]
# Note: Data augmentation and dropout layers are inactive at inference time.

# %%
img = tf.keras.utils.load_img(
    "/content/sandal2.png", target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)

print(score[0])
print(score[1])
print(score[2])
# Out:
# 1/1 [==============================] - 0s 25ms/step
# This image most likely belongs to Sandal with a 54.49 percent confidence.
# tf.Tensor(0.0009171883, shape=(), dtype=float32)
# tf.Tensor(0.54492396, shape=(), dtype=float32)
# tf.Tensor(0.45415887, shape=(), dtype=float32)

# %% [markdown]
# ## Use TensorFlow Lite
#
# TensorFlow Lite is a set of tools that enables on-device machine learning by helping developers run their models on mobile, embedded, and edge devices.

# %% [markdown]
# ### Convert the Keras Sequential model to a TensorFlow Lite model
#
# To use the trained model with on-device applications, first [convert it](https://www.tensorflow.org/lite/models/convert) to a smaller and more efficient model format called a [TensorFlow Lite](https://www.tensorflow.org/lite/) model.
#
# In this example, take the trained Keras Sequential model and use `tf.lite.TFLiteConverter.from_keras_model` to generate a [TensorFlow Lite](https://www.tensorflow.org/lite/) model:

# %%
# Convert the model.
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the model.
with open('model.tflite', 'wb') as f:
  f.write(tflite_model)

# %% [markdown]
# The TensorFlow Lite model you saved in the previous step can contain several function signatures. The Keras model converter API uses the default signature automatically. Learn more about [TensorFlow Lite signatures](https://www.tensorflow.org/lite/guide/signatures).

# %% [markdown]
# ### Run the TensorFlow Lite model
#
# You can access the TensorFlow Lite saved model signatures in Python via the `tf.lite.Interpreter` class.
#
# Load the model with the `Interpreter`:

# %%
TF_MODEL_FILE_PATH = 'model.tflite' # The default path to the saved TensorFlow Lite model

interpreter = tf.lite.Interpreter(model_path=TF_MODEL_FILE_PATH)

# %% [markdown]
# Print the signatures from the converted model to obtain the names of the inputs (and outputs):

# %%
interpreter.get_signature_list()

# %% [markdown]
# In this example, you have one default signature called `serving_default`. In addition, the name of the `'inputs'` is `'sequential_1_input'`, while the `'outputs'` are called `'outputs'`. You can look up these first and last Keras layer names when running `Model.summary`, as demonstrated earlier in this tutorial.
#
# Now you can test the loaded TensorFlow Model by performing inference on a sample image with `tf.lite.Interpreter.get_signature_runner` by passing the signature name as follows:

# %%
classify_lite = interpreter.get_signature_runner('serving_default')
classify_lite

# %% [markdown]
# Similar to what you did earlier in the tutorial, you can use the TensorFlow Lite model to classify images that weren't included in the training or validation sets.
#
# You have already tensorized that image and saved it as `img_array`. Now, pass it to the first argument (the name of the `'inputs'`) of the loaded TensorFlow Lite model (`predictions_lite`), compute softmax activations, and then print the prediction for the class with the highest computed probability.

# %%
predictions_lite = classify_lite(sequential_1_input=img_array)['outputs']
score_lite = tf.nn.softmax(predictions_lite)

# %%
print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score_lite)], 100 * np.max(score_lite))
)

# %% [markdown]
# The prediction generated by the lite model should be almost identical to the predictions generated by the original model:

# %%
print(np.max(np.abs(predictions - predictions_lite)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-a8dc412b5d25> in <module>
# ----> 1 print(np.max(np.abs(predictions - predictions_lite)))
#
# NameError: name 'predictions_lite' is not defined

# %% [markdown]
# Of the five classes—`'daisy'`, `'dandelion'`, `'roses'`, `'sunflowers'`, and `'tulips'`—the model should predict the image belongs to sunflowers, which is the same result as before the TensorFlow Lite conversion.

# %% [markdown]
# ## Next steps
#
# This tutorial showed how to train a model for image classification, test it, convert it to the TensorFlow Lite format for on-device applications (such as an image classification app), and perform inference with the TensorFlow Lite model with the Python API.
#
# You can learn more about TensorFlow Lite through [tutorials](https://www.tensorflow.org/lite/tutorials) and [guides](https://www.tensorflow.org/lite/guide).
